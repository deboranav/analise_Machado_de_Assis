# %%
#Caso precise ser rodado do colab e possua o Dataset no google drive
import sys
import pandas as pd
from os import path
from google.colab import drive

filepath = 'obras_machado_de_assis.csv'

# Juntar o caminho ao arquivo CSV. Conferir se colocou o caminho correto para o seu Drive

if 'google.colab' in sys.modules:
    drive.mount('/content/drive/', force_remount=True)
    drive_path = 'drive/MyDrive/Disciplinas/IMD1107 - NLP/Data'
    filepath = path.join(drive_path, filepath)

df = pd.read_csv(filepath)
df
# Out:
# Mounted at /content/drive/
#                    arquivo                     caminho completo categoria  \
# 0           revelacoes.pdf         ./pdf/crítica/revelacoes.pdf   crítica
# 1            magalhaes.pdf          ./pdf/crítica/magalhaes.pdf   crítica
# 2          novaGeracao.pdf        ./pdf/crítica/novaGeracao.pdf   crítica
# 3              eduardo.pdf            ./pdf/crítica/eduardo.pdf   crítica
# 4           cultoDever.pdf         ./pdf/crítica/cultoDever.pdf   crítica
# ..                     ...                                  ...       ...
# 111  contosFluminenses.pdf    ./pdf/conto/contosFluminenses.pdf     conto
# 112  paginasRecolhidas.pdf    ./pdf/conto/paginasRecolhidas.pdf     conto
# 113   trabalhadoresMar.pdf  ./pdf/tradução/trabalhadoresMar.pdf  tradução
# 114     suplicioMulher.pdf    ./pdf/tradução/suplicioMulher.pdf  tradução
# 115        oliverTwist.pdf       ./pdf/tradução/oliverTwist.pdf  tradução
#
#                 autor  paginas  \
# 0    Machado de Assis        5
# 1    Machado de Assis        4
# 2    Machado de Assis       22
# 3    Machado de Assis        2
# 4    Machado de Assis        5
# ..                ...      ...
# 111  Machado de Assis      164
# 112  Machado de Assis       43
# 113  Machado de Assis      247
# 114  Machado de Assis       29
# 115  Machado de Assis      125
#
#                                                 titulo  \
# 0    Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1    Magalhães de Azeredo: Horas sagradas; Mário de...
# 2                                       A nova geração
# 3                                        Eduardo Prado
# 4                     J.M. de Macedo: O culto do dever
# ..                                                 ...
# 111                                 Contos Fluminenses
# 112                                 Páginas Recolhidas
# 113                            Os Trabalhadores do Mar
# 114                             Suplício de uma mulher
# 115                                       Oliver Twist
#
#                                                 edicao  \
# 0    Texto-Fonte: Crítica Literária de Machado de A...
# 1    Texto-Fonte: Obra Completa de Machado de Assis...
# 2    Texto-Fonte: Obra Completa de Machado de Assis...
# 3    Texto-Fonte: Crítica Literária de Machado de A...
# 4    Texto-Fonte: Obra Completa de Machado de Assis...
# ..                                                 ...
# 111  Texto-fonte: Obra Completa, Machado de Assis, ...
# 112  Texto-fonte: Obra Completa, de Machado de Assi...
# 113  Texto-fonte: Os Trabalhadores do Mar, Victor H...
# 114  Texto-fonte: Teatro de Machado de Assis, org. ...
# 115  Texto-fonte: Oliver Twist, Charles Dickens, Tr...
#
#                                             publicacao  publicacao ano  \
# 0    Publicado originalmente no Diário do Rio de Ja...            1863
# 1         Publicado na Gazeta de Notícias, 07/12/1902.            1902
# 2    Publicado originalmente na Revista Brasileira,...            1879
# 3          Publicado em O Comércio de São Paulo, 1901.            1901
# 4    Publicado originalmente na “Semana Literária”,...            1866
# ..                                                 ...             ...
# 111  Publicado originalmente pela Editora Garnier, ...            1870
# 112  Publicado originalmente pela Editora Garnier, ...            1899
# 113  Publicado originalmente como Os Trabalhadores ...            1866
# 114  Publicada originalmente Obra Completa, Rio de ...            1865
# 115  Publicado originalmente em Jornal da Tarde, Ri...            1870
#
#            publicacao editora publicacao cidade  edicao ano  \
# 0    Diário do Rio de Janeiro    Rio de Janeiro        1938
# 1          Gazeta de Notícias    Rio de Janeiro        1994
# 2          Revista Brasileira    Rio de Janeiro        1994
# 3     O Comércio de São Paulo         São Paulo        1938
# 4    Diário do Rio de Janeiro    Rio de Janeiro        1994
# ..                        ...               ...         ...
# 111           Editora Garnier    Rio de Janeiro        1994
# 112           Editora Garnier    Rio de Janeiro        1994
# 113   Tipografia Perseverança    Rio de Janeiro        2002
# 114             W. M. Jackson    Rio de Janeiro        2003
# 115           Jornal da Tarde    Rio de Janeiro        2002
#
#             edicao editora   edicao cidade  \
# 0            W. M. Jackson  Rio de Janeiro
# 1             Nova Aguilar  Rio de Janeiro
# 2             Nova Aguilar  Rio de Janeiro
# 3            W. M. Jackson  Rio de Janeiro
# 4             Nova Aguilar  Rio de Janeiro
# ..                     ...             ...
# 111           Nova Aguilar  Rio de Janeiro
# 112           Nova Aguilar  Rio de Janeiro
# 113  Editora Nova Cultural       São Paulo
# 114         Martins Fontes       São Paulo
# 115                  Hedra       São Paulo
#
#                              edicao titulo edicao volume  \
# 0    Crítica Literária de Machado de Assis           NaN
# 1        Obra Completa de Machado de Assis           III
# 2        Obra Completa de Machado de Assis           III
# 3    Crítica Literária de Machado de Assis           NaN
# 4        Obra Completa de Machado de Assis           III
# ..                                     ...           ...
# 111        Obra Completa, Machado de Assis            II
# 112     Obra Completa, de Machado de Assis            II
# 113                Os Trabalhadores do Mar           NaN
# 114             Teatro de Machado de Assis           NaN
# 115                           Oliver Twist           NaN
#
#                                                  texto
# 0    Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1    Magalhães de Azeredo: Horas sagradas; Mário de...
# 2    A nova geração\n\nI\nHá entre nós uma nova ger...
# 3    Eduardo Prado\n\nA última vez que vi Eduardo P...
# 4    J.M. de Macedo: O culto do dever\n\nO autor d'...
# ..                                                 ...
# 111  Contos Fluminenses\n\nÍNDICE\nMISS DOLLAR\nLUÍ...
# 112  Páginas Recolhidas\n\nÍNDICE\nPREFÁCIO\nO CASO...
# 113  Os Trabalhadores do Mar\n\nÍNDICE\nDEDICATÓRIA...
# 114  Suplício de uma mulher\n\nDRAMA EM 3 ACTOS\npo...
# 115  Oliver Twist\n\nÍNDICE\nCAPÍTULO PRIMEIRO\nCAP...
#
# [116 rows x 17 columns]

# %%
import pandas as pd

# Carregar o CSV
df = pd.read_csv('Data/obras_machado_de_assis.csv')

# Verificar as primeiras linhas e a estrutura do DataFrame
print(df.head())
print(df.columns)  # Exibir o nome das colunas para referência
# Out:
#            arquivo               caminho completo categoria             autor  \
# 0   revelacoes.pdf   ./pdf/crítica/revelacoes.pdf   crítica  Machado de Assis
# 1    magalhaes.pdf    ./pdf/crítica/magalhaes.pdf   crítica  Machado de Assis
# 2  novaGeracao.pdf  ./pdf/crítica/novaGeracao.pdf   crítica  Machado de Assis
# 3      eduardo.pdf      ./pdf/crítica/eduardo.pdf   crítica  Machado de Assis
# 4   cultoDever.pdf   ./pdf/crítica/cultoDever.pdf   crítica  Machado de Assis
#
#    paginas                                             titulo  \
# 0        5  Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1        4  Magalhães de Azeredo: Horas sagradas; Mário de...
# 2       22                                     A nova geração
# 3        2                                      Eduardo Prado
# 4        5                   J.M. de Macedo: O culto do dever
#
#                                               edicao  \
# 0  Texto-Fonte: Crítica Literária de Machado de A...
# 1  Texto-Fonte: Obra Completa de Machado de Assis...
# 2  Texto-Fonte: Obra Completa de Machado de Assis...
# 3  Texto-Fonte: Crítica Literária de Machado de A...
# 4  Texto-Fonte: Obra Completa de Machado de Assis...
#
#                                           publicacao  publicacao ano  \
# 0  Publicado originalmente no Diário do Rio de Ja...            1863
# 1       Publicado na Gazeta de Notícias, 07/12/1902.            1902
# 2  Publicado originalmente na Revista Brasileira,...            1879
# 3        Publicado em O Comércio de São Paulo, 1901.            1901
# 4  Publicado originalmente na “Semana Literária”,...            1866
#
#          publicacao editora publicacao cidade  edicao ano edicao editora  \
# 0  Diário do Rio de Janeiro    Rio de Janeiro        1938  W. M. Jackson
# 1        Gazeta de Notícias    Rio de Janeiro        1994   Nova Aguilar
# 2        Revista Brasileira    Rio de Janeiro        1994   Nova Aguilar
# 3   O Comércio de São Paulo         São Paulo        1938  W. M. Jackson
# 4  Diário do Rio de Janeiro    Rio de Janeiro        1994   Nova Aguilar
#
#     edicao cidade                          edicao titulo edicao volume  \
# 0  Rio de Janeiro  Crítica Literária de Machado de Assis           NaN
# 1  Rio de Janeiro      Obra Completa de Machado de Assis           III
# 2  Rio de Janeiro      Obra Completa de Machado de Assis           III
# 3  Rio de Janeiro  Crítica Literária de Machado de Assis           NaN
# 4  Rio de Janeiro      Obra Completa de Machado de Assis           III
#
#                                                texto
# 0  Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1  Magalhães de Azeredo: Horas sagradas; Mário de...
# 2  A nova geração\n\nI\nHá entre nós uma nova ger...
# 3  Eduardo Prado\n\nA última vez que vi Eduardo P...
# 4  J.M. de Macedo: O culto do dever\n\nO autor d'...
# Index(['arquivo', 'caminho completo', 'categoria', 'autor', 'paginas',
#        'titulo', 'edicao', 'publicacao', 'publicacao ano',
#        'publicacao editora', 'publicacao cidade', 'edicao ano',
#        'edicao editora', 'edicao cidade', 'edicao titulo', 'edicao volume',
#        'texto'],
#       dtype='object')

# %%
# Filtrar apenas as linhas onde a categoria é 'romance'
romances_df = df[df['categoria'] == 'romance']

# Verificar o número de textos na categoria romance
print(f"Total de textos na categoria 'romance': {len(romances_df)}")

# Exibir o título e o início do conteúdo de alguns dos textos para verificação
for index, row in romances_df[['titulo', 'texto']].head(5).iterrows():
    print(f"Título: {row['titulo']}")
    print(f"Primeiras linhas do texto: {row['texto'][:500]}")  # Exibe os primeiros 500 caracteres
    print("-" * 80)
# Out:
# Total de textos na categoria 'romance': 10
# Título: Memórias Póstumas de Brás Cubas
# Primeiras linhas do texto: Memórias Póstumas de Brás Cubas
#
# Ao verme
# que
# primeiro roeu as frias carnes
# do meu cadáver
# dedico
# como saudosa lembrança
# estas
# Memórias Póstumas
# Prólogo da terceira edição
# A primeira edição destas Memórias Póstumas de Brás Cubas foi feita
# aos pedaços na Revista Brasileira, pelos anos de 1880. Postas mais
# tarde em livro, corrigi o texto em vários lugares. Agora que tive de o
# rever para a terceira edição, emendei ainda alguma coisa e suprimi
# duas ou três dúzias de linhas. Assim composta, sai novam
# --------------------------------------------------------------------------------
# Título: Esaú e Jacó
# Primeiras linhas do texto: Esaú e Jacó
#
# ADVERTÊNCIA
# Quando o Conselheiro Aires faleceu, acharam-se-lhe na secretária sete cadernos
# manuscritos, rijamente encapados em papelão. Cada um dos primeiros seis tinha
# o seu número de ordem, por algarismos romanos, I, II, III, IV, V, VI, escritos a
# tinta encarnada. O sétimo trazia este título: Último.
# A razão desta designação especial não se compreendeu então nem depois. Sim,
# era o último dos sete cadernos, com a particularidade de ser o mais grosso, mas
# não fazia parte do Memorial
# --------------------------------------------------------------------------------
# Título: Helena
# Primeiras linhas do texto: Helena
#
# ADVERTÊNCIA
# Esta nova edição de Helena sai com várias emendas de linguagem e
# outras, que não alteram a feição do livro. Ele é o mesmo da data em
# que o compus e imprimi, diverso do que o tempo me foi depois,
# correspondendo assim ao capítulo da história do meu espírito, naquele
# ano de 1876.
# Não me culpeis pelo que lhe achardes romanesco. Dos que então fiz,
# este me era particularmente prezado. Agora mesmo, que há tanto me
# fui a outras e diferentes páginas, ouço um eco remoto ao reler estas,
# --------------------------------------------------------------------------------
# Título: Ressurreição
# Primeiras linhas do texto: Ressurreição
#
# ADVERTÊNCIA DA NOVA EDIÇÃO
# Este foi o meu primeiro romance, escrito aí vão muitos anos. Dado em nova
# edição, não lhe altero a composição nem o estilo, apenas troco dois ou três
# vocábulos, e faço tais ou quais correções de ortografia. Como outros que
# vieram depois, e alguns contos e novelas de então, pertence à primeira fase da
# minha vida literária.
# M. DE A.
# 1905.
# ADVERTÊNCIA DA PRIMEIRA EDIÇÃO
# Não sei o que deva pensar deste livro; ignoro sobretudo o que pensará dele o
# leitor. A be
# --------------------------------------------------------------------------------
# Título: A Mão e a Luva
# Primeiras linhas do texto: A Mão e a Luva
#
# Advertência de 1907
# Os trinta e tantos anos decorridos do aparecimento desta novela à reimpressão
# que ora se faz parece que explicam as diferenças de composição e de maneira do
# autor. Se este não lhe daria agora a mesma feição, é certo que lha deu outrora,
# e, ao cabo, tudo pode servir a definir a mesma pessoa.
# Não existia, há muito, no mercado. O autor aceitou o conselho de confiar a
# reimpressão ao editor dos outros livros seus. Não lhe alterou nada; apenas
# emendou erros tipográf
# --------------------------------------------------------------------------------

# %%
romances_df.head()
# Out:
#              arquivo                caminho completo categoria  \
# 55  memoriasBras.pdf  ./pdf/romance/memoriasBras.pdf   romance
# 56          esau.pdf          ./pdf/romance/esau.pdf   romance
# 57        helena.pdf        ./pdf/romance/helena.pdf   romance
# 58  ressurreicao.pdf  ./pdf/romance/ressurreicao.pdf   romance
# 59       maoLuva.pdf       ./pdf/romance/maoLuva.pdf   romance
#
#                autor  paginas                           titulo  \
# 55  Machado de Assis      140  Memórias Póstumas de Brás Cubas
# 56  Machado de Assis      135                      Esaú e Jacó
# 57  Machado de Assis      139                           Helena
# 58  Machado de Assis       80                     Ressurreição
# 59  Machado de Assis       68                   A Mão e a Luva
#
#                                                edicao  \
# 55  Texto-fonte: Obra Completa, Machado de Assis, ...
# 56  Texto-fonte: Obra Completa, Machado de Assis, ...
# 57  Texto-fonte: Obra Completa, de Machado de Assi...
# 58  Texto-fonte: Obra Completa, Machado de Assis, ...
# 59  Texto-fonte: Obra Completa, Machado de Assis, ...
#
#                                            publicacao  publicacao ano  \
# 55  Publicado originalmente em folhetins, a partir...            1880
# 56  Publicado originalmente pela Editora Garnier, ...            1904
# 57  Publicado originalmente em folhetins, a partir...            1876
# 58  Publicado originalmente pela Editora Garnier, ...            1872
# 59  Publicado originalmente em folhetins, a partir...            1874
#
#     publicacao editora publicacao cidade  edicao ano edicao editora  \
# 55  Revista Brasileira    Rio de Janeiro        1994   Nova Aguilar
# 56     Editora Garnier    Rio de Janeiro        1994   Nova Aguilar
# 57             O Globo    Rio de Janeiro        1994   Nova Aguilar
# 58     Editora Garnier    Rio de Janeiro        1994   Nova Aguilar
# 59             O Globo    Rio de Janeiro        1994   Nova Aguilar
#
#      edicao cidade                       edicao titulo edicao volume  \
# 55  Rio de Janeiro     Obra Completa, Machado de Assis           NaN
# 56  Rio de Janeiro     Obra Completa, Machado de Assis           NaN
# 57  Rio de Janeiro  Obra Completa, de Machado de Assis             I
# 58  Rio de Janeiro     Obra Completa, Machado de Assis           NaN
# 59  Rio de Janeiro     Obra Completa, Machado de Assis           NaN
#
#                                                 texto
# 55  Memórias Póstumas de Brás Cubas\n\nAo verme\nq...
# 56  Esaú e Jacó\n\nADVERTÊNCIA\nQuando o Conselhei...
# 57  Helena\n\nADVERTÊNCIA\nEsta nova edição de Hel...
# 58  Ressurreição\n\nADVERTÊNCIA DA NOVA EDIÇÃO\nEs...
# 59  A Mão e a Luva\n\nAdvertência de 1907\nOs trin...

# %%
romances_df['texto'].iloc[5]
# Out:
# 'Memorial de Aires\n\nEm Lixboa, sobre lo mar,\nBarcas novas mandey lavrar...\nCantiga de Joham Zorro.\nPara veer meu amigo\nQue talhou preyto comigo,\nAlá vou, madre.\nPara veer meu amado\nQue mig’a preyto talhado,\nAlá vou, madre.\nCantiga d’el rei Dom Denis.\nAdvertência\nQuem me leu Esaú e Jacó talvez reconheça estas palavras do prefácio:\n“Nos lazeres do ofício escrevia o Memorial, que, apesar das páginas\nmortas ou escuras, apenas daria (e talvez dê) para matar o tempo da\nbarca de Petrópolis”.\nReferia-me ao Conselheiro Aires. Tratando-se agora de imprimir o\nMemorial, achou-se que a parte relativa a uns dois anos (1888-1889),\nse for decotada de algumas circunstâncias, anedotas, descrições e\nreflexões, — pode dar uma narração seguida, que talvez interesse,\napesar da forma de diário que tem. Não houve pachorra de a redigir à\nmaneira daquela outra, — nem pachorra, nem habilidade. Vai como\nestava, mas desbastada e estreita, conservando só o que liga o mesmo\nassunto. O resto aparecerá um dia, se aparecer algum dia.\nM. de A.\n1888\n9 de janeiro\nOra bem, faz hoje um ano que voltei definitivamente da Europa. O que\nme lembrou esta data foi, estando a beber café, o pregão de um\nvendedor de vassouras e espanadores: "Vai vassouras! vai\nespanadores!" Costumo ouvi-lo outras manhãs, mas desta vez trouxeme à memória o dia do desembarque, quando cheguei aposentado à\nminha terra, ao meu Catete, à minha língua. Era o mesmo que ouvi há\num ano, em 1887, e talvez fosse a mesma boca.\nDurante os meus trinta e tantos anos de diplomacia algumas vezes vim\nao Brasil, com licença. O mais do tempo vivi fora, em várias partes, e\nnão foi pouco. Cuidei que não acabaria de me habituar novamente a\nesta outra vida de cá. Pois acabei. Certamente ainda me lembram\ncoisas e pessoas de longe, diversões, paisagens, costumes, mas não\nmorro de saudades por nada. Aqui estou, aqui vivo, aqui morrerei.\nCinco horas da tarde\nRecebi agora um bilhete de mana Rita, que aqui vai colado:\n9 de janeiro\n“Mano,\nSó agora me lembrou que faz hoje um ano que você\nvoltou da Europa aposentado. Já é tarde para ir ao\ncemitério de São João Batista, em visita ao jazigo da\nfamília, dar graças pelo seu regresso; irei amanhã de\nmanhã, e peço a você que me espere para ir comigo.\nSaudades da\nVelha mana,\nRita”.\nNão vejo necessidade disso, mas respondi que sim.\n10 de janeiro\nFomos ao cemitério. Rita, apesar da alegria do motivo, não pôde reter\nalgumas velhas lágrimas de saudade pelo marido que lá está no jazigo,\ncom meu pai e minha mãe. Ela ainda agora o ama, como no dia em\nque o perdeu, lá se vão tantos anos. No caixão do defunto mandou\nguardar um molho dos seus cabelos, então pretos, enquanto os mais\ndeles ficaram a embranquecer cá fora.\nNão é feio o nosso jazigo; podia ser um pouco mais simples, — a\ninscrição e uma cruz, — mas o que está é bem feito. Achei-o novo\ndemais, isso sim. Rita fá-lo lavar todos os meses, e isto impede que\nenvelheça. Ora, eu creio que um velho túmulo dá melhor impressão do\noficio, se tem as negruras do tempo, que tudo consome. O contrário\nparece sempre da véspera.\nRita orou diante dele alguns minutos, enquanto eu circulava os olhos\npelas sepulturas próximas. Em quase todas havia a mesma antiga\nsúplica da nossa: "Orai por ele! Orai por ela!" Rita me disse depois, em\ncaminho, que é seu costume atender ao pedido das outras, rezando\numa prece por todos os que ali estão. Talvez seja a única. A mana é\nboa criatura, não menos que alegre.\nA impressão que me dava o total do cemitério é a que me deram\nsempre outros; tudo ali estava parado. Os gestos das figuras, anjos e\noutras, eram diversos, mas imóveis. Só alguns pássaros davam sinal\nde vida, buscando-se entre si e pousando nas ramagens, pipilando ou\ngorjeando. Os arbustos viviam calados, na verdura e nas flores.\nJá perto do portão, à saída, falei a mana Rita de uma senhora que eu\nvira ao pé de outra sepultura, ao lado esquerdo do cruzeiro, enquanto\nela rezava. Era ...

# %%
import re
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

# Função para remover espaços excessivos
def remove_excessive_spaces(text: str) -> str:
    return re.sub(r'\s+', ' ', text).strip()

# Função para corrigir pontuações isoladas
def fix_isolated_commas_in_text(text: str) -> str:
    text = re.sub(r' ([.,:;!?])', r'\1', text)
    return text.strip()

# Ajustando o pipeline de limpeza
pipeline_clean_text_literario = Pipeline([
    ('remove_excessive_spaces', FunctionTransformer(remove_excessive_spaces)),
    ('fix_isolated_commas_in_text', FunctionTransformer(fix_isolated_commas_in_text)),
])

# %%
# Aplicação do pipeline ajustado
romances_df.loc[:, 'texto_limpo'] = romances_df['texto'].apply(pipeline_clean_text_literario.transform)

# %%
# Exibir o título e o início do conteúdo de alguns dos textos para verificação
for index, row in romances_df[['titulo', 'texto_limpo']].head(5).iterrows():
    print(f"Título: {row['titulo']}")
    print(f"Primeiras linhas do texto: {row['texto_limpo'][:500]}")  # Exibe os primeiros 500 caracteres
    print("-" * 80)
# Out:
# Título: Memórias Póstumas de Brás Cubas
# Primeiras linhas do texto: Memórias Póstumas de Brás Cubas Ao verme que primeiro roeu as frias carnes do meu cadáver dedico como saudosa lembrança estas Memórias Póstumas Prólogo da terceira edição A primeira edição destas Memórias Póstumas de Brás Cubas foi feita aos pedaços na Revista Brasileira, pelos anos de 1880. Postas mais tarde em livro, corrigi o texto em vários lugares. Agora que tive de o rever para a terceira edição, emendei ainda alguma coisa e suprimi duas ou três dúzias de linhas. Assim composta, sai novame
# --------------------------------------------------------------------------------
# Título: Esaú e Jacó
# Primeiras linhas do texto: Esaú e Jacó ADVERTÊNCIA Quando o Conselheiro Aires faleceu, acharam-se-lhe na secretária sete cadernos manuscritos, rijamente encapados em papelão. Cada um dos primeiros seis tinha o seu número de ordem, por algarismos romanos, I, II, III, IV, V, VI, escritos a tinta encarnada. O sétimo trazia este título: Último. A razão desta designação especial não se compreendeu então nem depois. Sim, era o último dos sete cadernos, com a particularidade de ser o mais grosso, mas não fazia parte do Memorial,
# --------------------------------------------------------------------------------
# Título: Helena
# Primeiras linhas do texto: Helena ADVERTÊNCIA Esta nova edição de Helena sai com várias emendas de linguagem e outras, que não alteram a feição do livro. Ele é o mesmo da data em que o compus e imprimi, diverso do que o tempo me foi depois, correspondendo assim ao capítulo da história do meu espírito, naquele ano de 1876. Não me culpeis pelo que lhe achardes romanesco. Dos que então fiz, este me era particularmente prezado. Agora mesmo, que há tanto me fui a outras e diferentes páginas, ouço um eco remoto ao reler estas,
# --------------------------------------------------------------------------------
# Título: Ressurreição
# Primeiras linhas do texto: Ressurreição ADVERTÊNCIA DA NOVA EDIÇÃO Este foi o meu primeiro romance, escrito aí vão muitos anos. Dado em nova edição, não lhe altero a composição nem o estilo, apenas troco dois ou três vocábulos, e faço tais ou quais correções de ortografia. Como outros que vieram depois, e alguns contos e novelas de então, pertence à primeira fase da minha vida literária. M. DE A. 1905. ADVERTÊNCIA DA PRIMEIRA EDIÇÃO Não sei o que deva pensar deste livro; ignoro sobretudo o que pensará dele o leitor. A ben
# --------------------------------------------------------------------------------
# Título: A Mão e a Luva
# Primeiras linhas do texto: A Mão e a Luva Advertência de 1907 Os trinta e tantos anos decorridos do aparecimento desta novela à reimpressão que ora se faz parece que explicam as diferenças de composição e de maneira do autor. Se este não lhe daria agora a mesma feição, é certo que lha deu outrora, e, ao cabo, tudo pode servir a definir a mesma pessoa. Não existia, há muito, no mercado. O autor aceitou o conselho de confiar a reimpressão ao editor dos outros livros seus. Não lhe alterou nada; apenas emendou erros tipográfi
# --------------------------------------------------------------------------------
